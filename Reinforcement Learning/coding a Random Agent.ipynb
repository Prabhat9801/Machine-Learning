# %%
import gymnasium as gym
import numpy as np
import pandas as pd

# %%
cliffEnv = gym.make("CliffWalking-v1")

# %%
done = False

# %%
state = cliffEnv.reset()

# %%
done = False
while not done:
    print(cliffEnv.render())
    action = int(np.random.randint(low = 0, high = 4, size = 1))
    print(state, "-->" ,["Up","right","down","left"][action])
    state, reward, terminated, truncated, info = cliffEnv.step(action)
    done = terminated or truncated
    print(state,reward,done,info)
cliffEnv.close()
# Out:
# None
# 47 --> right
# 47 -1 True {'prob': 1.0}
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/toy_text/cliffwalking.py:218: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CliffWalking-v1", render_mode="rgb_array")
#   gym.logger.warn(
# /tmp/ipython-input-37-1808834550.py:4: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   action = int(np.random.randint(low = 0, high = 4, size = 1))

# %%
import gymnasium as gym
import numpy as np

# Create the environment with render_mode set to "ansi"
cliffEnv = gym.make("CliffWalking-v1", render_mode="ansi")
state, info = cliffEnv.reset()

done = False
while not done:
    output = cliffEnv.render()  # This returns a string representation
    print(output)

    # Select a random action
    action = np.random.randint(0, 4)  # 0: Up, 1: Right, 2: Down, 3: Left
    print(f"State {state} --> Action: {['Up','Right','Down','Left'][action]}")

    # Take the action
    state, reward, terminated, truncated, info = cliffEnv.step(action)
    done = terminated or truncated

    print(f"New State: {state}, Reward: {reward}, Done: {done}, Info: {info}")

cliffEnv.close()
# Out:
# Streaming output truncated to the last 5000 lines.
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# x  C  C  C  C  C  C  C  C  C  C  T
#
#
# State 36 --> Action: Left
# New State: 36, Reward: -1, Done: False, Info: {'prob': 1.0}
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# x  C  C  C  C  C  C  C  C  C  C  T
#
#
# State 36 --> Action: Down
# New State: 36, Reward: -1, Done: False, Info: {'prob': 1.0}
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# x  C  C  C  C  C  C  C  C  C  C  T
#
#
# State 36 --> Action: Left
# New State: 36, Reward: -1, Done: False, Info: {'prob': 1.0}
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# x  C  C  C  C  C  C  C  C  C  C  T
#
#
# State 36 --> Action: Down
# ...
